# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # used for plotting graphs
import seaborn as sns
from sklearn.impute import SimpleImputer # used for handling missing data
from sklearn import preprocessing
import plotly.express as px # used for plotting choropleth

# %% [markdown]
# **Importing the dataset and performing basic commands**

# %%
data=pd.read_csv("/Life Expectancy Dataset.csv")

# %%
data.head(5)
# Out:
#        Country  Year Status of country  Life Expectancy   Adult Mortality  \
# 0  Afghanistan  2015        Developing              65.0              263
# 1  Afghanistan  2014        Developing              59.9              271
# 2  Afghanistan  2013        Developing              59.9              268
# 3  Afghanistan  2012        Developing              59.5              272
# 4  Afghanistan  2011        Developing              59.2              275
#
#    Infant Deaths  Alcohol  Hepatitis B  Measles   Polio  Diphtheria   \
# 0             62     0.01         65.0      1154    6.0         65.0
# 1             64     0.01         62.0       492   58.0         62.0
# 2             66     0.01         64.0       430   62.0         64.0
# 3             69     0.01         67.0      2787   67.0         67.0
# 4             71     0.01         68.0      3013   68.0         68.0
#
#     HIV/AIDS  Under-five Deaths    BMI   Population         GDP  \
# 0        0.1                  83   19.1  33736494.0  584.259210
# 1        0.1                  86   18.6    327582.0  612.696514
# 2        0.1                  89   18.1  31731688.0  631.744976
# 3        0.1                  93   17.6   3696958.0  669.959000
# 4        0.1                  97   17.2   2978599.0   63.537231
#
#     thinness  1-19 years   thinness 5-9 years  Schooling
# 0                   17.2                 17.3       10.1
# 1                   17.5                 17.5       10.0
# 2                   17.7                 17.7        9.9
# 3                   17.9                 18.0        9.8
# 4                   18.2                 18.2        9.5

# %%
#Viewing the first and last 20 record to analyse the data properly
data.head(20)
# Out:
#         Country  Year Status of country  Life Expectancy   Adult Mortality  \
# 0   Afghanistan  2015        Developing              65.0              263
# 1   Afghanistan  2014        Developing              59.9              271
# 2   Afghanistan  2013        Developing              59.9              268
# 3   Afghanistan  2012        Developing              59.5              272
# 4   Afghanistan  2011        Developing              59.2              275
# 5   Afghanistan  2010        Developing              58.8              279
# 6   Afghanistan  2009        Developing              58.6              281
# 7   Afghanistan  2008        Developing              58.1              287
# 8   Afghanistan  2007        Developing              57.5              295
# 9   Afghanistan  2006        Developing              57.3              295
# 10  Afghanistan  2005        Developing              57.3              291
# 11  Afghanistan  2004        Developing              57.0              293
# 12  Afghanistan  2003        Developing              56.7              295
# 13  Afghanistan  2002        Developing              56.2                3
# 14  Afghanistan  2001        Developing              55.3              316
# 15  Afghanistan  2000        Developing              54.8              321
# 16      Albania  2015        Developing              77.8               74
# 17      Albania  2014        Developing              77.5                8
# 18      Albania  2013        Developing              77.2               84
# 19      Albania  2012        Developing              76.9               86
#
#     Infant Deaths  Alcohol  Hepatitis B  Measles   Polio  Diphtheria   \
# 0              62     0.01         65.0      1154    6.0         65.0
# 1              64     0.01         62.0       492   58.0         62.0
# 2              66     0.01         64.0       430   62.0         64.0
# 3              69     0.01         67.0      2787   67.0         67.0
# 4              71     0.01         68.0      3013   68.0         68.0
# 5              74     0.01         66.0      1989   66.0         66.0
# 6              77     0.01         63.0      2861   63.0         63.0
# 7              80     0.03         64.0      1599   64.0         64.0
# 8              82     0.02         63.0      1141   63.0         63.0
# 9              84     0.03         64.0      1990   58.0         58.0
# 10             85     0.02         66.0      1296   58.0         58.0
# 11             87     0.02         67.0       466    5.0          5.0
# 12             87     0.01         65.0       798   41.0         41.0
# 13             88     0.01         64.0      2486   36.0         36.0
# 14             88     0.01         63.0      8762   35.0         33.0
# 15             88     0.01         62.0      6532   24.0         24.0
# 16              0     4.60         99.0         0   99.0         99.0
# 17              0     4.51         98.0         0   98.0         98.0
# 18              0     4.76         99.0         0   99.0         99.0
# 19              0     5.14         99.0         9   99.0         99.0
#
#      HIV/AIDS  Under-five Deaths    BMI   Population          GDP  \
# 0         0.1                  83   19.1  33736494.0   584.259210
# 1         0.1                  86   18.6    327582.0   612.696514
# 2         0.1                  89   18.1  31731688.0   631.744976
# 3         0.1                  93   17.6   3696958.0   669.959000
# 4         0.1                  97   17.2   2978599.0    63.537231
# 5         0.1                 102   16.7   2883167.0   553.328940
# 6         0.1                 106   16.2    284331.0   445.893298
# 7         0.1                 110   15.7   2729431.0   373.361116
# 8         0.1                 113   15.2  26616792.0   369.835796
# 9         0.1                 116   14.7   2589345.0   272.563770
# 10        0.1                 118   14.2    257798.0    25.294130
# 11        0.1                 120   13.8  24118979.0   219.141353
# 12        0.1                 122   13.4   2364851.0   198.728544
# 13        0.1                 122   13.0  21979923.0   187.845950
# 14        0.1                 122   12.6   2966463.0   117.496980
# 15        0.1                 122   12.2    293756.0   114.560000
# 16        0.1                   0   58.0     28873.0  3954.227830
# 17        0.1                   1   57.2    288914.0  4575.763787
# 18        0.1                   1   56.5    289592.0  4414.723140
# 19        0.1                   1   55.8      2941.0  4247.614380
#
#      thinness  1-19 years   thinness 5-9 years  Schooling
# 0                    17.2                 17.3       10.1
# 1                    17.5                 17.5       10.0
# 2                    17.7                 17.7        9.9
# 3                    17.9                 18.0        9.8
# 4                    18.2                 18.2        9.5
# 5                    18.4                 18.4        9.2
# 6                    18.6                 18.7        8.9
# 7                    18.8                 18.9        8.7
# 8                    19.0                 19.1        8.4
# 9                    19.2                 19.3        8.1
# 10                   19.3                 19.5        7.9
# 11                   19.5                 19.7        6.8
# 12                   19.7                 19.9        6.5
# 13                   19.9                  2.2        6.2
# 14                    2.1                  2.4        5.9
# 15                    2.3                  2.5        5.5
# 16                    1.2                  1.3       14.2
# 17                    1.2                  1.3       14.2
# 18                    1.3                  1.4       14.2
# 19                    1.3                  1.4       14.2

# %%
data.tail(20)
# Out:
#        Country  Year Status of country  Life Expectancy   Adult Mortality  \
# 1116  Viet Nam  2003        Developing              74.0              137
# 1117  Viet Nam  2002        Developing              73.8              137
# 1118  Viet Nam  2001        Developing              73.6              138
# 1119  Viet Nam  2000        Developing              73.4              139
# 1120  Zimbabwe  2015        Developing              67.0              336
# 1121  Zimbabwe  2014        Developing              59.2              371
# 1122  Zimbabwe  2013        Developing              58.0              399
# 1123  Zimbabwe  2012        Developing              56.6              429
# 1124  Zimbabwe  2011        Developing              54.9              464
# 1125  Zimbabwe  2010        Developing              52.4              527
# 1126  Zimbabwe  2009        Developing              50.0              587
# 1127  Zimbabwe  2008        Developing              48.2              632
# 1128  Zimbabwe  2007        Developing              46.6               67
# 1129  Zimbabwe  2006        Developing              45.4                7
# 1130  Zimbabwe  2005        Developing              44.6              717
# 1131  Zimbabwe  2004        Developing              44.3              723
# 1132  Zimbabwe  2003        Developing              44.5              715
# 1133  Zimbabwe  2002        Developing              44.8               73
# 1134  Zimbabwe  2001        Developing              45.3              686
# 1135  Zimbabwe  2000        Developing              46.0              665
#
#       Infant Deaths  Alcohol  Hepatitis B  Measles   Polio  Diphtheria   \
# 1116             30     2.19         78.0      2297   96.0         99.0
# 1117             30     2.03          NaN      6755   92.0         75.0
# 1118             32     1.84          NaN     12058   96.0         96.0
# 1119             33     1.60          NaN     16512   96.0         96.0
# 1120             22      NaN         87.0         0   88.0         87.0
# 1121             23     6.50         91.0         0   92.0         91.0
# 1122             25     6.39         95.0         0   95.0         95.0
# 1123             26     6.09         97.0         0   95.0         95.0
# 1124             28     6.00         94.0         0   93.0         93.0
# 1125             29     5.21          9.0      9696   89.0         89.0
# 1126             30     4.64         73.0       853   69.0         73.0
# 1127             30     3.56         75.0         0   75.0         75.0
# 1128             29     3.88         72.0       242   73.0         73.0
# 1129             28     4.57         68.0       212   71.0          7.0
# 1130             28     4.14         65.0       420   69.0         68.0
# 1131             27     4.36         68.0        31   67.0         65.0
# 1132             26     4.06          7.0       998    7.0         68.0
# 1133             25     4.43         73.0       304   73.0         71.0
# 1134             25     1.72         76.0       529   76.0         75.0
# 1135             24     1.68         79.0      1483   78.0         78.0
#
#        HIV/AIDS  Under-five Deaths    BMI   Population         GDP  \
# 1116        0.2                  37    1.4     75946.0         NaN
# 1117        0.2                  39    1.0    751652.0         NaN
# 1118        0.1                  41    9.6    751857.0         NaN
# 1119        0.1                  43    9.2    751884.0         NaN
# 1120        6.2                  32   31.8    752263.0  118.693830
# 1121        6.3                  34   31.3     75331.0  127.474620
# 1122        6.8                  36    3.8    171161.0  111.227396
# 1123        8.8                  39    3.3   1572466.0  955.648466
# 1124       13.3                  42   29.9   1431776.0  839.927936
# 1125       15.7                  44   29.4    128921.0  713.635620
# 1126       18.1                  45   29.0    114554.0   65.824121
# 1127       20.5                  46   28.6   9999617.0  325.678573
# 1128       23.7                  46   28.2    985287.0  396.998217
# 1129       26.8                  45   27.9     97529.0  414.796232
# 1130       30.3                  43   27.5   9556889.0  444.765750
# 1131       33.6                  42   27.1    949457.0  454.366654
# 1132       36.7                  41   26.7    926344.0  453.351155
# 1133       39.8                  40   26.3   9119178.0   57.348340
# 1134       42.1                  39   25.9   8976552.0  548.587312
# 1135       43.5                  39   25.5   8834733.0  547.358878
#
#        thinness  1-19 years   thinness 5-9 years  Schooling
# 1116                   15.6                  NaN       10.9
# 1117                   15.6                  NaN       10.7
# 1118                   15.7                  NaN       10.6
# 1119                   15.8                  NaN       10.4
# 1120                    5.6                  NaN       10.3
# 1121                    5.9                  NaN       10.3
# 1122                    6.2                  NaN       10.4
# 1123                    6.5                  NaN        9.8
# 1124                    6.8                  NaN       10.1
# 1125                    7.1                  NaN       10.0
# 1126                    7.5                  NaN        9.9
# 1127                    7.8                  NaN        9.7
# 1128                    8.2                  NaN        9.6
# 1129                    8.6                  NaN        9.5
# 1130                    9.0                  NaN        9.3
# 1131                    9.4                  NaN        9.2
# 1132                    9.8                  NaN        9.5
# 1133                    1.2                  NaN       10.0
# 1134                    1.6                  NaN        9.8
# 1135                   11.0                  NaN        9.8

# %%
#To check the number of non-null values per column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1136 entries, 0 to 1135
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                1136 non-null   object
#  1   Year                   1136 non-null   int64
#  2   Status of country      1136 non-null   object
#  3   Life Expectancy        1136 non-null   float64
#  4   Adult Mortality        1136 non-null   int64
#  5   Infant Deaths          1136 non-null   int64
#  6   Alcohol                1056 non-null   float64
#  7   Hepatitis B            907 non-null    float64
#  8   Measles                1136 non-null   int64
#  9   Polio                  1125 non-null   float64
#  10  Diphtheria             1125 non-null   float64
#  11   HIV/AIDS              1136 non-null   float64
#  12  Under-five Deaths      1136 non-null   int64
#  13   BMI                   1120 non-null   float64
#  14  Population             890 non-null    float64
#  15  GDP                    1028 non-null   float64
#  16   thinness  1-19 years  270 non-null    float64
#  17   thinness 5-9 years    107 non-null    float64
#  18  Schooling              695 non-null    float64
# dtypes: float64(12), int64(5), object(2)
# memory usage: 168.8+ KB

# %%
df_desc = pd.DataFrame(data.describe())

# %%
df_desc
# Out:
#               Year  Life Expectancy   Adult Mortality  Infant Deaths  \
# count  1136.000000       1136.000000      1136.000000    1136.000000
# mean   2007.500000         73.114965       132.024648      44.989437
# std       4.611803          8.907496       113.230510     173.463124
# min    2000.000000         44.300000         1.000000       0.000000
# 25%    2003.750000         68.400000        65.000000       0.000000
# 50%    2007.500000         74.650000        94.000000       2.000000
# 75%    2011.250000         79.400000       172.000000      27.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  Hepatitis B       Measles         Polio  Diphtheria   \
# count  1056.000000   907.000000    1136.000000  1125.000000  1125.000000
# mean      5.448106    80.942668    3134.353873    86.502222    86.445333
# std       4.090507    25.383874   11515.779990    20.401513    20.431160
# min       0.010000     2.000000       0.000000     5.000000     5.000000
# 25%       1.600000    76.500000       1.000000    86.000000    86.000000
# 50%       5.525000    93.000000      60.000000    94.000000    94.000000
# 75%       9.072500    96.000000     820.250000    97.000000    97.000000
# max      14.270000    99.000000  131441.000000    99.000000    99.000000
#
#           HIV/AIDS  Under-five Deaths          BMI     Population  \
# count  1136.000000          1136.00000  1120.000000  8.900000e+02
# mean      1.543926            58.53169    40.859375  8.874432e+06
# std       5.940855           229.37147    20.839210  2.333344e+07
# min       0.100000             0.00000     1.000000  4.300000e+01
# 25%       0.100000             1.00000    21.175000  2.158010e+05
# 50%       0.100000             3.00000    52.200000  1.292528e+06
# 75%       0.100000            35.00000    58.400000  7.439154e+06
# max      50.600000          2500.00000    71.400000  1.986867e+08
#
#                 GDP   thinness  1-19 years   thinness 5-9 years   Schooling
# count   1028.000000             270.000000           107.000000  695.000000
# mean   11999.419440               5.618889             4.259813   13.229640
# std    17696.062397               5.510299             5.634645    3.498207
# min        1.681350               0.400000             0.600000    0.000000
# 25%      707.076555               1.300000             1.000000   11.000000
# 50%     3655.302552               4.900000             1.900000   13.300000
# 75%    14424.476900               8.075000             5.800000   15.850000
# max    87998.444680              19.900000            19.900000   20.400000

# %%
df_desc.to_csv('/described_data.csv')

# %%
#Renaming the column to an appropriate name
data.rename(columns={"Status of country":"Country Status"},inplace=True)

# %%
#Displays renamed column
data.head()
# Out:
#        Country  Year Country Status  Life Expectancy   Adult Mortality  \
# 0  Afghanistan  2015     Developing              65.0              263
# 1  Afghanistan  2014     Developing              59.9              271
# 2  Afghanistan  2013     Developing              59.9              268
# 3  Afghanistan  2012     Developing              59.5              272
# 4  Afghanistan  2011     Developing              59.2              275
#
#    Infant Deaths  Alcohol  Hepatitis B  Measles   Polio  Diphtheria   \
# 0             62     0.01         65.0      1154    6.0         65.0
# 1             64     0.01         62.0       492   58.0         62.0
# 2             66     0.01         64.0       430   62.0         64.0
# 3             69     0.01         67.0      2787   67.0         67.0
# 4             71     0.01         68.0      3013   68.0         68.0
#
#     HIV/AIDS  Under-five Deaths    BMI   Population         GDP  \
# 0        0.1                  83   19.1  33736494.0  584.259210
# 1        0.1                  86   18.6    327582.0  612.696514
# 2        0.1                  89   18.1  31731688.0  631.744976
# 3        0.1                  93   17.6   3696958.0  669.959000
# 4        0.1                  97   17.2   2978599.0   63.537231
#
#     thinness  1-19 years   thinness 5-9 years  Schooling
# 0                   17.2                 17.3       10.1
# 1                   17.5                 17.5       10.0
# 2                   17.7                 17.7        9.9
# 3                   17.9                 18.0        9.8
# 4                   18.2                 18.2        9.5

# %% [markdown]
# **Handling Missing Values**

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Country Status', 'Life Expectancy ',
#        'Adult Mortality', 'Infant Deaths', 'Alcohol', 'Hepatitis B',
#        'Measles ', 'Polio', 'Diphtheria ', ' HIV/AIDS', 'Under-five Deaths ',
#        ' BMI ', 'Population', 'GDP', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Schooling'],
#       dtype='object')

# %%
#We take the count of Country column as reference because this column has zero null values as can be seen from the info command
data_count = data["Country"].count()

# %%
#Calculating the percentage of null values in each column
(data.isnull().sum()/data_count) * 100
# Out:
# Country                   0.000000
# Year                      0.000000
# Country Status            0.000000
# Life Expectancy           0.000000
# Adult Mortality           0.000000
# Infant Deaths             0.000000
# Alcohol                   7.042254
# Hepatitis B              20.158451
# Measles                   0.000000
# Polio                     0.968310
# Diphtheria                0.968310
#  HIV/AIDS                 0.000000
# Under-five Deaths         0.000000
#  BMI                      1.408451
# Population               21.654930
# GDP                       9.507042
#  thinness  1-19 years    76.232394
#  thinness 5-9 years      90.580986
# Schooling                38.820423
# dtype: float64

# %% [markdown]
# ***Here, we need to treat only numerical variables as the only categorical variables(Country and Country Status) have zero null values***

# %% [markdown]
# **Handling missing values by DELETION**

# %%
'''The following columns are dropped as they have a large percent of null values(about 90% and 76%) & the column schooling is not much important
for our analysis of the target variable(Life Expectancy)'''

data.drop(columns=[' thinness  1-19 years', ' thinness 5-9 years', 'Schooling'],axis=1,inplace=True)

# %%
#Shows that the columns above have been dropped
data.head()
# Out:
#        Country  Year Country Status  Life Expectancy   Adult Mortality  \
# 0  Afghanistan  2015     Developing              65.0              263
# 1  Afghanistan  2014     Developing              59.9              271
# 2  Afghanistan  2013     Developing              59.9              268
# 3  Afghanistan  2012     Developing              59.5              272
# 4  Afghanistan  2011     Developing              59.2              275
#
#    Infant Deaths  Alcohol  Hepatitis B  Measles   Polio  Diphtheria   \
# 0             62     0.01         65.0      1154    6.0         65.0
# 1             64     0.01         62.0       492   58.0         62.0
# 2             66     0.01         64.0       430   62.0         64.0
# 3             69     0.01         67.0      2787   67.0         67.0
# 4             71     0.01         68.0      3013   68.0         68.0
#
#     HIV/AIDS  Under-five Deaths    BMI   Population         GDP
# 0        0.1                  83   19.1  33736494.0  584.259210
# 1        0.1                  86   18.6    327582.0  612.696514
# 2        0.1                  89   18.1  31731688.0  631.744976
# 3        0.1                  93   17.6   3696958.0  669.959000
# 4        0.1                  97   17.2   2978599.0   63.537231

# %% [markdown]
# **Handling missing values by IMPUTING**

# %%
#Imputing the missing values by the mean value
imputer = SimpleImputer(missing_values=np.NaN, strategy='mean')

# %%
imputer = imputer.fit(data.iloc[:, 3:])
data.iloc[:, 3:] = imputer.transform(data.iloc[:, 3:])
# Out:
# <ipython-input-18-ff2bbaf89187>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data.iloc[:, 3:] = imputer.transform(data.iloc[:, 3:])

# %%
#As can be seen below, our dataset now has 0 null values
data.isnull().sum()
# Out:
# Country               0
# Year                  0
# Country Status        0
# Life Expectancy       0
# Adult Mortality       0
# Infant Deaths         0
# Alcohol               0
# Hepatitis B           0
# Measles               0
# Polio                 0
# Diphtheria            0
#  HIV/AIDS             0
# Under-five Deaths     0
#  BMI                  0
# Population            0
# GDP                   0
# dtype: int64

# %%
data.head(20)
# Out:
#         Country  Year Country Status  Life Expectancy   Adult Mortality  \
# 0   Afghanistan  2015     Developing              65.0            263.0
# 1   Afghanistan  2014     Developing              59.9            271.0
# 2   Afghanistan  2013     Developing              59.9            268.0
# 3   Afghanistan  2012     Developing              59.5            272.0
# 4   Afghanistan  2011     Developing              59.2            275.0
# 5   Afghanistan  2010     Developing              58.8            279.0
# 6   Afghanistan  2009     Developing              58.6            281.0
# 7   Afghanistan  2008     Developing              58.1            287.0
# 8   Afghanistan  2007     Developing              57.5            295.0
# 9   Afghanistan  2006     Developing              57.3            295.0
# 10  Afghanistan  2005     Developing              57.3            291.0
# 11  Afghanistan  2004     Developing              57.0            293.0
# 12  Afghanistan  2003     Developing              56.7            295.0
# 13  Afghanistan  2002     Developing              56.2              3.0
# 14  Afghanistan  2001     Developing              55.3            316.0
# 15  Afghanistan  2000     Developing              54.8            321.0
# 16      Albania  2015     Developing              77.8             74.0
# 17      Albania  2014     Developing              77.5              8.0
# 18      Albania  2013     Developing              77.2             84.0
# 19      Albania  2012     Developing              76.9             86.0
#
#     Infant Deaths  Alcohol  Hepatitis B  Measles   Polio  Diphtheria   \
# 0            62.0     0.01         65.0    1154.0    6.0         65.0
# 1            64.0     0.01         62.0     492.0   58.0         62.0
# 2            66.0     0.01         64.0     430.0   62.0         64.0
# 3            69.0     0.01         67.0    2787.0   67.0         67.0
# 4            71.0     0.01         68.0    3013.0   68.0         68.0
# 5            74.0     0.01         66.0    1989.0   66.0         66.0
# 6            77.0     0.01         63.0    2861.0   63.0         63.0
# 7            80.0     0.03         64.0    1599.0   64.0         64.0
# 8            82.0     0.02         63.0    1141.0   63.0         63.0
# 9            84.0     0.03         64.0    1990.0   58.0         58.0
# 10           85.0     0.02         66.0    1296.0   58.0         58.0
# 11           87.0     0.02         67.0     466.0    5.0          5.0
# 12           87.0     0.01         65.0     798.0   41.0         41.0
# 13           88.0     0.01         64.0    2486.0   36.0         36.0
# 14           88.0     0.01         63.0    8762.0   35.0         33.0
# 15           88.0     0.01         62.0    6532.0   24.0         24.0
# 16            0.0     4.60         99.0       0.0   99.0         99.0
# 17            0.0     4.51         98.0       0.0   98.0         98.0
# 18            0.0     4.76         99.0       0.0   99.0         99.0
# 19            0.0     5.14         99.0       9.0   99.0         99.0
#
#      HIV/AIDS  Under-five Deaths    BMI   Population          GDP
# 0         0.1                83.0   19.1  33736494.0   584.259210
# 1         0.1                86.0   18.6    327582.0   612.696514
# 2         0.1                89.0   18.1  31731688.0   631.744976
# 3         0.1                93.0   17.6   3696958.0   669.959000
# 4         0.1                97.0   17.2   2978599.0    63.537231
# 5         0.1               102.0   16.7   2883167.0   553.328940
# 6         0.1               106.0   16.2    284331.0   445.893298
# 7         0.1               110.0   15.7   2729431.0   373.361116
# 8         0.1               113.0   15.2  26616792.0   369.835796
# 9         0.1               116.0   14.7   2589345.0   272.563770
# 10        0.1               118.0   14.2    257798.0    25.294130
# 11        0.1               120.0   13.8  24118979.0   219.141353
# 12        0.1               122.0   13.4   2364851.0   198.728544
# 13        0.1               122.0   13.0  21979923.0   187.845950
# 14        0.1               122.0   12.6   2966463.0   117.496980
# 15        0.1               122.0   12.2    293756.0   114.560000
# 16        0.1                 0.0   58.0     28873.0  3954.227830
# 17        0.1                 1.0   57.2    288914.0  4575.763787
# 18        0.1                 1.0   56.5    289592.0  4414.723140
# 19        0.1                 1.0   55.8      2941.0  4247.614380

# %% [markdown]
# ***ONE-HOT/ DUMMY ENCODING***

# %%
#Though our data has non-null categorical variables, but still we do one-hot encoding to make our dataset more useful for analysis and visualization
data["Country Status"].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
data=pd.get_dummies(data,columns=["Country Status"])

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Life Expectancy ', 'Adult Mortality',
#        'Infant Deaths', 'Alcohol', 'Hepatitis B', 'Measles ', 'Polio',
#        'Diphtheria ', ' HIV/AIDS', 'Under-five Deaths ', ' BMI ', 'Population',
#        'GDP', 'Country Status_Developed', 'Country Status_Developing'],
#       dtype='object')

# %%
data[['Country','Country Status_Developing','Country Status_Developed']].head(25)
# Out:
#         Country  Country Status_Developing  Country Status_Developed
# 0   Afghanistan                          1                         0
# 1   Afghanistan                          1                         0
# 2   Afghanistan                          1                         0
# 3   Afghanistan                          1                         0
# 4   Afghanistan                          1                         0
# 5   Afghanistan                          1                         0
# 6   Afghanistan                          1                         0
# 7   Afghanistan                          1                         0
# 8   Afghanistan                          1                         0
# 9   Afghanistan                          1                         0
# 10  Afghanistan                          1                         0
# 11  Afghanistan                          1                         0
# 12  Afghanistan                          1                         0
# 13  Afghanistan                          1                         0
# 14  Afghanistan                          1                         0
# 15  Afghanistan                          1                         0
# 16      Albania                          1                         0
# 17      Albania                          1                         0
# 18      Albania                          1                         0
# 19      Albania                          1                         0
# 20      Albania                          1                         0
# 21      Albania                          1                         0
# 22      Albania                          1                         0
# 23      Albania                          1                         0
# 24      Albania                          1                         0

# %%
data.head()
# Out:
#        Country  Year  Life Expectancy   Adult Mortality  Infant Deaths  \
# 0  Afghanistan  2015              65.0            263.0           62.0
# 1  Afghanistan  2014              59.9            271.0           64.0
# 2  Afghanistan  2013              59.9            268.0           66.0
# 3  Afghanistan  2012              59.5            272.0           69.0
# 4  Afghanistan  2011              59.2            275.0           71.0
#
#    Alcohol  Hepatitis B  Measles   Polio  Diphtheria    HIV/AIDS  \
# 0     0.01         65.0    1154.0    6.0         65.0        0.1
# 1     0.01         62.0     492.0   58.0         62.0        0.1
# 2     0.01         64.0     430.0   62.0         64.0        0.1
# 3     0.01         67.0    2787.0   67.0         67.0        0.1
# 4     0.01         68.0    3013.0   68.0         68.0        0.1
#
#    Under-five Deaths    BMI   Population         GDP  \
# 0                83.0   19.1  33736494.0  584.259210
# 1                86.0   18.6    327582.0  612.696514
# 2                89.0   18.1  31731688.0  631.744976
# 3                93.0   17.6   3696958.0  669.959000
# 4                97.0   17.2   2978599.0   63.537231
#
#    Country Status_Developed  Country Status_Developing
# 0                         0                          1
# 1                         0                          1
# 2                         0                          1
# 3                         0                          1
# 4                         0                          1

# %% [markdown]
# **Deriving a new column from existing column to be used later in analysis and visualization**

# %%
#Creating a new dataframe with average life expectancy
avg_life_expec=data.groupby(["Country"])['Life Expectancy '].mean().reset_index()
avg_life_expec_df=pd.DataFrame(avg_life_expec)
avg_life_expec_df
# Out:
#                                               Country  Life Expectancy
# 0                                         Afghanistan          58.19375
# 1                                             Albania          75.15625
# 2                                             Algeria          73.61875
# 3                                           Argentina          75.15625
# 4                                           Australia          81.81250
# ..                                                ...               ...
# 66  United Kingdom of Great Britain and Northern I...          80.79375
# 67                           United States of America          78.06250
# 68                                            Uruguay          76.07500
# 69                                           Viet Nam          74.77500
# 70                                           Zimbabwe          50.48750
#
# [71 rows x 2 columns]

# %%
avg_life_expec_df.rename(columns={"Life Expectancy ":"Avg_life_exp_per_cntry"},inplace=True)

# %%
avg_life_expec_df.head()
# Out:
#        Country  Avg_life_exp_per_cntry
# 0  Afghanistan                58.19375
# 1      Albania                75.15625
# 2      Algeria                73.61875
# 3    Argentina                75.15625
# 4    Australia                81.81250

# %%
#Merge/Join the newly created dataframe with our original dataset
data=pd.merge(data,avg_life_expec,on="Country",how="left")

# %%
data.head()
# Out:
#        Country  Year  Life Expectancy   Adult Mortality  Infant Deaths  \
# 0  Afghanistan  2015              65.0            263.0           62.0
# 1  Afghanistan  2014              59.9            271.0           64.0
# 2  Afghanistan  2013              59.9            268.0           66.0
# 3  Afghanistan  2012              59.5            272.0           69.0
# 4  Afghanistan  2011              59.2            275.0           71.0
#
#    Alcohol  Hepatitis B  Measles   Polio  Diphtheria    HIV/AIDS  \
# 0     0.01         65.0    1154.0    6.0         65.0        0.1
# 1     0.01         62.0     492.0   58.0         62.0        0.1
# 2     0.01         64.0     430.0   62.0         64.0        0.1
# 3     0.01         67.0    2787.0   67.0         67.0        0.1
# 4     0.01         68.0    3013.0   68.0         68.0        0.1
#
#    Under-five Deaths    BMI   Population         GDP  \
# 0                83.0   19.1  33736494.0  584.259210
# 1                86.0   18.6    327582.0  612.696514
# 2                89.0   18.1  31731688.0  631.744976
# 3                93.0   17.6   3696958.0  669.959000
# 4                97.0   17.2   2978599.0   63.537231
#
#    Country Status_Developed  Country Status_Developing  Avg_life_exp_per_cntry
# 0                         0                          1                58.19375
# 1                         0                          1                58.19375
# 2                         0                          1                58.19375
# 3                         0                          1                58.19375
# 4                         0                          1                58.19375

# %%
#Creating a new dataframe with average GDP
avg_GDP=data.groupby(["Country"])['GDP'].mean().reset_index()
avg_GDP_df=pd.DataFrame(avg_GDP)
avg_GDP_df
# Out:
#                                               Country           GDP
# 0                                         Afghanistan    340.015425
# 1                                             Albania   2119.726679
# 2                                             Algeria   2847.853392
# 3                                           Argentina   6998.575103
# 4                                           Australia  34637.565047
# ..                                                ...           ...
# 66  United Kingdom of Great Britain and Northern I...  11999.419440
# 67                           United States of America  11999.419440
# 68                                            Uruguay   7192.584875
# 69                                           Viet Nam  11999.419440
# 70                                           Zimbabwe    410.980194
#
# [71 rows x 2 columns]

# %%
avg_GDP_df.rename(columns={"GDP":"Avg_GDP_per_cntry"},inplace=True)

# %%
avg_GDP_df.head()
# Out:
#        Country  Avg_GDP_per_cntry
# 0  Afghanistan         340.015425
# 1      Albania        2119.726679
# 2      Algeria        2847.853392
# 3    Argentina        6998.575103
# 4    Australia       34637.565047

# %%
#Merge/Join the newly created dataframe with our original dataset
data=pd.merge(data,avg_GDP_df,on="Country",how="left")

# %%
data.head()
# Out:
#        Country  Year  Life Expectancy   Adult Mortality  Infant Deaths  \
# 0  Afghanistan  2015              65.0            263.0           62.0
# 1  Afghanistan  2014              59.9            271.0           64.0
# 2  Afghanistan  2013              59.9            268.0           66.0
# 3  Afghanistan  2012              59.5            272.0           69.0
# 4  Afghanistan  2011              59.2            275.0           71.0
#
#    Alcohol  Hepatitis B  Measles   Polio  Diphtheria    HIV/AIDS  \
# 0     0.01         65.0    1154.0    6.0         65.0        0.1
# 1     0.01         62.0     492.0   58.0         62.0        0.1
# 2     0.01         64.0     430.0   62.0         64.0        0.1
# 3     0.01         67.0    2787.0   67.0         67.0        0.1
# 4     0.01         68.0    3013.0   68.0         68.0        0.1
#
#    Under-five Deaths    BMI   Population         GDP  \
# 0                83.0   19.1  33736494.0  584.259210
# 1                86.0   18.6    327582.0  612.696514
# 2                89.0   18.1  31731688.0  631.744976
# 3                93.0   17.6   3696958.0  669.959000
# 4                97.0   17.2   2978599.0   63.537231
#
#    Country Status_Developed  Country Status_Developing  \
# 0                         0                          1
# 1                         0                          1
# 2                         0                          1
# 3                         0                          1
# 4                         0                          1
#
#    Avg_life_exp_per_cntry  Avg_GDP_per_cntry
# 0                58.19375         340.015425
# 1                58.19375         340.015425
# 2                58.19375         340.015425
# 3                58.19375         340.015425
# 4                58.19375         340.015425

# %% [markdown]
# **DATA VISUALIZATION**

# %% [markdown]
# ***Choropleth (Average Life Expectancy of all countires in 2015)***

# %%
top = data[data['Year'] == data['Year'].max()]
top['Year'].unique()
# Out:
# array([2015])

# %%
world = top.groupby('Country')['Life Expectancy '].mean().reset_index()
world.rename(columns={'Life Expectancy ':"Average_Life_Expectancy"},inplace=True)
world.head()
# Out:
#        Country  Average_Life_Expectancy
# 0  Afghanistan                     65.0
# 1      Albania                     77.8
# 2      Algeria                     75.6
# 3    Argentina                     76.3
# 4    Australia                     82.8

# %%
figure = px.choropleth(world,locations='Country',locationmode='country names',color='Average_Life_Expectancy',
                       hover_name = 'Country',range_color=[4,100],color_continuous_scale='Blues',
                       title="Average Life Expectancy of Countries")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f4a8ca50-13bb-4c2a-bcd6-545e999b3d07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4a8ca50-13bb-4c2a-bcd6-545e999b3d07")) {                    Plotly.newPlot(                        "f4a8ca50-13bb-4c2a-bcd6-545e999b3d07",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{location}<br>Average_Life_Expectancy=%{z}<extra></extra>","hovertext":["Afghanistan","Albania","Algeria","Argentina","Australia","Austria","Bahamas","Bangladesh","Belgium","Bhutan","Brazil","Bulgaria","Cambodia","Cameroon","Canada","Chile","China","Colombia","Congo","Costa Rica","Cuba","Cyprus","Denmark","Egypt","Fiji","Finland","France","Georgia","Germany","Greece","Iceland","India","Indonesia","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Kuwait","Liberia","Malaysia","Maldives","Myanmar","Nepal","Netherlands","New Zealand","Norway","Pakistan","Philippines","Poland","Saudi Arabia","Seychelles","Singapore","South Africa","South Sudan","Spain","Sri Lanka","Swaziland","Sweden","Switzerland","Thailand","Turkey","Uganda","Ukraine","United Arab Emirates","United Kingdom of Great Britain and Northern Ireland","United States of America","Uruguay","Viet Nam","Zimbabwe"],"locationmode":"country names","locations":["Afghanistan","Albania","Algeria","Argentina","Australia","Austria","Bahamas","Bangladesh","Belgium","Bhutan","Brazil","Bulgaria","Cambodia","Cameroon","Canada","Chile","China","Colombia","Congo","Costa Rica","Cuba","Cyprus","Denmark","Egypt","Fiji","Finland","France","Georgia","Germany","Greece","Iceland","India","Indonesia","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Kuwait","Liberia","Malaysia","Maldives","Myanmar","Nepal","Netherlands","New Zealand","Norway","Pakistan","Philippines","Poland","Saudi Arabia","Seychelles","Singapore","South Africa","South Sudan","Spain","Sri Lanka","Swaziland","Sweden","Switzerland","Thailand","Turkey","Uganda","Ukraine","United Arab Emirates","United Kingdom of Great Britain and Northern Ireland","United States of America","Uruguay","Viet Nam","Zimbabwe"],"name":"","z":[65.0,77.8,75.6,76.3,82.8,81.5,76.1,71.8,81.1,69.8,75.0,74.5,68.7,57.3,82.2,85.0,76.1,74.8,64.7,79.6,79.1,85.0,86.0,79.0,69.9,81.1,82.4,74.4,81.0,81.0,82.7,68.3,69.1,68.9,81.4,82.5,82.7,76.2,83.7,74.7,61.4,75.0,78.5,66.6,69.2,81.9,81.6,81.8,66.4,68.5,77.5,74.5,73.2,83.1,62.9,57.3,82.8,74.9,58.9,82.4,83.4,74.9,75.8,62.3,71.3,77.1,81.2,79.3,77.0,76.0,67.0],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca2 ...

# %% [markdown]
# ***Pair Grid Graph (Life Expectancy vs Year for all countires)***

# %%
g3 = sns.FacetGrid(data, col="Country", col_wrap=3, height=4)
g3 = (g3.map(plt.plot, "Year", "Life Expectancy ").add_legend())

# %% [markdown]
# ***Barplot (Average GDP per country)***

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=data['Avg_GDP_per_cntry'], y=data["Country"])
plt.title("Average GDP per country")
plt.show()

# %% [markdown]
# ***Bar Chart***

# %%
#Creating different datasets for developed and developing countries
#Developed Countries
developed_countries = data[data['Country Status_Developed']==1].reset_index(drop=True)
developed_countries = developed_countries.groupby('Country')['Life Expectancy '].mean().reset_index()
developed_countries.rename(columns = {'Life Expectancy ':'Avg_life_expec_developed'},inplace = True)
developed_countries.head()
# Out:
#      Country  Avg_life_expec_developed
# 0  Australia                  81.81250
# 1    Austria                  81.48125
# 2    Belgium                  80.68125
# 3   Bulgaria                  72.85000
# 4     Cyprus                  79.67500

# %%
mean_developed = developed_countries['Avg_life_expec_developed'].mean()
print("Average Life Expectancy of Developed Countries: ",mean_developed)
# Out:
# Average Life Expectancy of Developed Countries:  80.54345238095236

# %%
#Developing Countries
developing_countries=data[data['Country Status_Developing']==1].reset_index(drop=True)
developing_countries = developing_countries.groupby('Country')['Life Expectancy '].mean().reset_index()
developing_countries.rename(columns = {'Life Expectancy ':'Avg_life_expec_developing'},inplace = True)
developing_countries.head()
# Out:
#        Country  Avg_life_expec_developing
# 0  Afghanistan                   58.19375
# 1      Albania                   75.15625
# 2      Algeria                   73.61875
# 3    Argentina                   75.15625
# 4      Bahamas                   74.28750

# %%
mean_developing = developing_countries['Avg_life_expec_developing'].mean()
print("Average Life Expectancy of Developed Countries: ", mean_developing)
# Out:
# Average Life Expectancy of Developed Countries:  69.995

# %% [markdown]
# ***Bar Chart (Average Life Expectancy of Developed and Developing Countries)***

# %%
plt.figure(figsize=(7,5))
labels = ('mean_developed', 'mean_developing')
values = (mean_developed, mean_developing)
plt.bar(labels, values, width=0.2, color="green")
plt.xlabel("Type of Country")
plt.ylabel("Average Life Expectancy")
plt.show()

# %% [markdown]
# **DETAILED ANALYSIS AND VISUALIZATION OF TWO COUNTIRES (one with maximum Life Expectancy and other with minimum Life Expectancy**

# %%
#Creating a datframe containing records of country with maximum life expectancy
max_life_expec_cntry=data[data['Avg_life_exp_per_cntry']==data['Avg_life_exp_per_cntry'].max()].reset_index(drop=True)

# %%
#Creating a datframe containing records of country with minimum life expectancy
min_life_expec_cntry=data[data['Avg_life_exp_per_cntry']==data['Avg_life_exp_per_cntry'].min()].reset_index(drop=True)

# %%
print("Country with maximum life expectancy: ",max_life_expec_cntry['Country'].unique())
# Out:
# Country with maximum life expectancy:  ['Japan']

# %%
print("Country with maximum life expectancy: ",min_life_expec_cntry['Country'].unique())
# Out:
# Country with maximum life expectancy:  ['Zimbabwe']

# %% [markdown]
# ***ANALYSIS AND VISUALIZATION OF JAPAN (Max Life Expectancy)***

# %%
max_life_expec_cntry
# Out:
#    Country  Year  Life Expectancy   Adult Mortality  Infant Deaths   Alcohol  \
# 0    Japan  2015              83.7             55.0            2.0  5.448106
# 1    Japan  2014              83.5             57.0            2.0  0.010000
# 2    Japan  2013              83.5             56.0            2.0  7.550000
# 3    Japan  2012              83.3             58.0            2.0  7.390000
# 4    Japan  2011              82.5             64.0            3.0  7.390000
# 5    Japan  2010              83.0             62.0            3.0  6.900000
# 6    Japan  2009              83.0             64.0            3.0  7.090000
# 7    Japan  2008              82.7             66.0            3.0  7.110000
# 8    Japan  2007              82.6             67.0            3.0  7.290000
# 9    Japan  2006              82.4             68.0            3.0  7.490000
# 10   Japan  2005              82.0             69.0            3.0  7.990000
# 11   Japan  2004              82.1             68.0            3.0  7.700000
# 12   Japan  2003              81.9              7.0            3.0  7.830000
# 13   Japan  2002              81.8              7.0            3.0  7.870000
# 14   Japan  2001              81.5             72.0            4.0  8.030000
# 15   Japan  2000              81.1             74.0            4.0  7.970000
#
#     Hepatitis B  Measles   Polio  Diphtheria    HIV/AIDS  Under-five Deaths   \
# 0     80.942668      35.0   99.0         96.0        0.1                 3.0
# 1     80.942668     462.0   99.0         96.0        0.1                 3.0
# 2     80.942668     229.0   99.0         96.0        0.1                 3.0
# 3     80.942668     228.0   99.0         97.0        0.1                 3.0
# 4     80.942668     434.0   96.0         97.0        0.1                 4.0
# 5     80.942668     450.0   98.0         97.0        0.1                 4.0
# 6     80.942668     741.0   99.0         97.0        0.1                 4.0
# 7     80.942668   11015.0   98.0         98.0        0.1                 4.0
# 8     80.942668       0.0   97.0         98.0        0.1                 4.0
# 9     80.942668     520.0   95.0         98.0        0.1                 4.0
# 10    80.942668       0.0   95.0         98.0        0.1                 4.0
# 11    80.942668    8752.0   97.0         99.0        0.1                 4.0
# 12    80.942668    8286.0   97.0         97.0        0.1                 5.0
# 13    80.942668   33812.0   89.0         96.0        0.1                 5.0
# 14    80.942668   22552.0   81.0         95.0        0.1                 5.0
# 15    80.942668   22497.0   98.0         85.0        0.1                 5.0
#
#      BMI     Population          GDP  Country Status_Developed  \
# 0    29.0  8.874432e+06  34474.13736                         1
# 1    28.6  8.874432e+06   3896.21151                         1
# 2    28.2  8.874432e+06   4454.44746                         1
# 3    27.8  8.874432e+06   4863.47665                         1
# 4    27.4  8.874432e+06  48167.99727                         1
# 5    26.9  8.874432e+06   4457.67639                         1
# 6    26.4  8.874432e+06   4855.17564                         1
# 7    25.9  8.874432e+06  39339.29757                         1
# 8    25.4  8.874432e+06  35275.22843                         1
# 9    24.9  8.874432e+06  35433.98896                         1
# 10   24.4  8.874432e+06  37217.64873                         1
# 11   23.8  8.874432e+06  37688.72234                         1
# 12   23.4  8.874432e+06   3488.39920                         1
# 13   22.9  8.874432e+06  32289.35540                         1
# 14   22.5  8.874432e+06  33846.46564                         1
# 15   22.2  8.874432e+06  38532.48800                         1
#
#     Country Status_Developing  Avg_life_exp_per_cntry  Avg_GDP_per_cntry
# 0                           0                 82.5375       24892.544784
# 1                           0                 82.5375       24892.544784
# 2                           0                 82.5375       24892.544784
# 3                           0                 82.5375       24892.544784
# 4                           0                 82.5375       24892.544784
# 5                           0                 82.5375       24892.544784
# 6                           0                 82.5375       24892.544784
# 7                           0                 82.5375       24892.544784
# 8                           0                 82.5375       24892.544784
# 9                           0                 82.5375       24892.544784
# 10                          0                 82.5375       24892.544784
# 11                          0                 82.5375       24892.544784
# 12                          0                 82.5375       24892.544784
# 13                          0                 82.5375       24892.544784
# 14                          0                 82.5375       24892.544784
# 15                          0                 82.5375       24892.544784

# %% [markdown]
# ***Time Series Graph (Life Expectancy of Japan)***

# %%
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry['Life Expectancy '], marker='o')

# Labelling
plt.xlabel("Year")
plt.ylabel("Life Expectancy")
plt.title("Life Expectancy vs Year (Japan- 2000 - 2015)")

# Display
plt.show()

# %% [markdown]
# ***Line Graph (Adult Mortality and Infant Deaths and Under-Five Deaths vs Year)***

# %%
plt.figure(figsize=(7,5))
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry["Adult Mortality"], color='red', label='Adult Mortality')
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry["Infant Deaths"], color='blue', label='Infant Deaths')
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry["Under-five Deaths "], color='green', label='Under-Five Deaths')
plt.xlabel("Year")
plt.ylabel("Parameter")
plt.title('Adult Mortality and Infant Deaths and Under-Five Deaths vs Year')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ***Box Plot (Adult Mortality (Japan) )***

# %%
#As can be seen from the above graph, the column Adult Mortality(of Japan) has outliers present in it which can be verified from the box plot below
plt.boxplot(max_life_expec_cntry["Adult Mortality"])
plt.xlabel("Distribution")
plt.ylabel("Parameter")
# Out:
# Text(0, 0.5, 'Parameter')

# %% [markdown]
# **Treating Outliers**

# %%
q1 = max_life_expec_cntry['Adult Mortality'].quantile(0.25)
q2 = max_life_expec_cntry['Adult Mortality'].quantile(0.75)
iqr=q2-q1
upper_limit = q2 + 1.5 * iqr
lower_limit = q1 - 1.5 * iqr
def limit_imputer(value):
  if value > upper_limit:
    return upper_limit
  elif value < lower_limit:
    return lower_limit
  else:
    return value
max_life_expec_cntry['Adult Mortality'] = max_life_expec_cntry['Adult Mortality'].apply(limit_imputer)

# %%
#As can be seen from the box plot below, the outliers in Adult Mortality(of Japan) have been treated
plt.boxplot(max_life_expec_cntry["Adult Mortality"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fca01aad9c0>,
#   <matplotlib.lines.Line2D at 0x7fca01aac160>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fca01aafa00>,
#   <matplotlib.lines.Line2D at 0x7fca01aafca0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fca01aaec20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fca01aaff40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fca01ad4220>],
#  'means': []}

# %%
max_life_expec_cntry
# Out:
#    Country  Year  Life Expectancy   Adult Mortality  Infant Deaths   Alcohol  \
# 0    Japan  2015              83.7           55.000            2.0  5.448106
# 1    Japan  2014              83.5           57.000            2.0  0.010000
# 2    Japan  2013              83.5           56.000            2.0  7.550000
# 3    Japan  2012              83.3           58.000            2.0  7.390000
# 4    Japan  2011              82.5           64.000            3.0  7.390000
# 5    Japan  2010              83.0           62.000            3.0  6.900000
# 6    Japan  2009              83.0           64.000            3.0  7.090000
# 7    Japan  2008              82.7           66.000            3.0  7.110000
# 8    Japan  2007              82.6           67.000            3.0  7.290000
# 9    Japan  2006              82.4           68.000            3.0  7.490000
# 10   Japan  2005              82.0           69.000            3.0  7.990000
# 11   Japan  2004              82.1           68.000            3.0  7.700000
# 12   Japan  2003              81.9           39.875            3.0  7.830000
# 13   Japan  2002              81.8           39.875            3.0  7.870000
# 14   Japan  2001              81.5           72.000            4.0  8.030000
# 15   Japan  2000              81.1           74.000            4.0  7.970000
#
#     Hepatitis B  Measles   Polio  Diphtheria    HIV/AIDS  Under-five Deaths   \
# 0     80.942668      35.0   99.0         96.0        0.1                 3.0
# 1     80.942668     462.0   99.0         96.0        0.1                 3.0
# 2     80.942668     229.0   99.0         96.0        0.1                 3.0
# 3     80.942668     228.0   99.0         97.0        0.1                 3.0
# 4     80.942668     434.0   96.0         97.0        0.1                 4.0
# 5     80.942668     450.0   98.0         97.0        0.1                 4.0
# 6     80.942668     741.0   99.0         97.0        0.1                 4.0
# 7     80.942668   11015.0   98.0         98.0        0.1                 4.0
# 8     80.942668       0.0   97.0         98.0        0.1                 4.0
# 9     80.942668     520.0   95.0         98.0        0.1                 4.0
# 10    80.942668       0.0   95.0         98.0        0.1                 4.0
# 11    80.942668    8752.0   97.0         99.0        0.1                 4.0
# 12    80.942668    8286.0   97.0         97.0        0.1                 5.0
# 13    80.942668   33812.0   89.0         96.0        0.1                 5.0
# 14    80.942668   22552.0   81.0         95.0        0.1                 5.0
# 15    80.942668   22497.0   98.0         85.0        0.1                 5.0
#
#      BMI     Population          GDP  Country Status_Developed  \
# 0    29.0  8.874432e+06  34474.13736                         1
# 1    28.6  8.874432e+06   3896.21151                         1
# 2    28.2  8.874432e+06   4454.44746                         1
# 3    27.8  8.874432e+06   4863.47665                         1
# 4    27.4  8.874432e+06  48167.99727                         1
# 5    26.9  8.874432e+06   4457.67639                         1
# 6    26.4  8.874432e+06   4855.17564                         1
# 7    25.9  8.874432e+06  39339.29757                         1
# 8    25.4  8.874432e+06  35275.22843                         1
# 9    24.9  8.874432e+06  35433.98896                         1
# 10   24.4  8.874432e+06  37217.64873                         1
# 11   23.8  8.874432e+06  37688.72234                         1
# 12   23.4  8.874432e+06   3488.39920                         1
# 13   22.9  8.874432e+06  32289.35540                         1
# 14   22.5  8.874432e+06  33846.46564                         1
# 15   22.2  8.874432e+06  38532.48800                         1
#
#     Country Status_Developing  Avg_life_exp_per_cntry  Avg_GDP_per_cntry
# 0                           0                 82.5375       24892.544784
# 1                           0                 82.5375       24892.544784
# 2                           0                 82.5375       24892.544784
# 3                           0                 82.5375       24892.544784
# 4                           0                 82.5375       24892.544784
# 5                           0                 82.5375       24892.544784
# 6                           0                 82.5375       24892.544784
# 7                           0                 82.5375       24892.544784
# 8                           0                 82.5375       24892.544784
# 9                           0                 82.5375       24892.544784
# 10                          0                 82.5375       24892.544784
# 11                          0                 82.5375       24892.544784
# 12                          0                 82.5375       24892.544784
# 13                          0                 82.5375       24892.544784
# 14                          0                 82.5375       24892.544784
# 15                          0                 82.5375       24892.544784

# %% [markdown]
# ***Line Graph (Adult Mortality and Infant Deaths and Under-Five Deaths vs Year) after treating outliers***

# %%
plt.figure(figsize=(7,5))
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry["Adult Mortality"], color='red', label='Adult Mortality')
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry["Infant Deaths"], color='blue', label='Infant Deaths')
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry["Under-five Deaths "], color='green', label='Under-Five Deaths')
plt.xlabel("Year")
plt.ylabel("Parameter")
plt.title('Adult Mortality and Infant Deaths and Under-Five Deaths vs Year')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ***Bar Graph (Year vs GDP)***

# %%
plt.figure(figsize=(15,8))
plt.bar(max_life_expec_cntry['Year'], max_life_expec_cntry['GDP'], width=0.5, color="purple")
plt.title('Year vs GDP of Japan')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()

# %% [markdown]
# ***Pie Chart (average persons suffering from various diseases in Japan)***

# %%
df=max_life_expec_cntry.iloc[:,5:11]
df=pd.DataFrame(df.mean())
df
# Out:
#                        0
# Alcohol         6.941132
# Hepatitis B    80.942668
# Measles      6875.812500
# Polio          96.000000
# Diphtheria     96.250000
#  HIV/AIDS       0.100000

# %%
#Since HIV/AIDS has very less value, it would not be properly visible in pie chart and hence is dropped
df=max_life_expec_cntry.iloc[:,5:10]
df=pd.DataFrame(df.mean())
df
# Out:
#                        0
# Alcohol         6.941132
# Hepatitis B    80.942668
# Measles      6875.812500
# Polio          96.000000
# Diphtheria     96.250000

# %% [markdown]
# ***Pie Chart (Diseases in Japan)***

# %% [markdown]
# ***ANALYSIS AND VISUALIZATION OF ZIMBABWE (Min Life Expectancy)***

# %%
min_life_expec_cntry
# Out:
#      Country  Year  Life Expectancy   Adult Mortality  Infant Deaths  \
# 0   Zimbabwe  2015              67.0            336.0           22.0
# 1   Zimbabwe  2014              59.2            371.0           23.0
# 2   Zimbabwe  2013              58.0            399.0           25.0
# 3   Zimbabwe  2012              56.6            429.0           26.0
# 4   Zimbabwe  2011              54.9            464.0           28.0
# 5   Zimbabwe  2010              52.4            527.0           29.0
# 6   Zimbabwe  2009              50.0            587.0           30.0
# 7   Zimbabwe  2008              48.2            632.0           30.0
# 8   Zimbabwe  2007              46.6             67.0           29.0
# 9   Zimbabwe  2006              45.4              7.0           28.0
# 10  Zimbabwe  2005              44.6            717.0           28.0
# 11  Zimbabwe  2004              44.3            723.0           27.0
# 12  Zimbabwe  2003              44.5            715.0           26.0
# 13  Zimbabwe  2002              44.8             73.0           25.0
# 14  Zimbabwe  2001              45.3            686.0           25.0
# 15  Zimbabwe  2000              46.0            665.0           24.0
#
#      Alcohol  Hepatitis B  Measles   Polio  Diphtheria    HIV/AIDS  \
# 0   5.448106         87.0       0.0   88.0         87.0        6.2
# 1   6.500000         91.0       0.0   92.0         91.0        6.3
# 2   6.390000         95.0       0.0   95.0         95.0        6.8
# 3   6.090000         97.0       0.0   95.0         95.0        8.8
# 4   6.000000         94.0       0.0   93.0         93.0       13.3
# 5   5.210000          9.0    9696.0   89.0         89.0       15.7
# 6   4.640000         73.0     853.0   69.0         73.0       18.1
# 7   3.560000         75.0       0.0   75.0         75.0       20.5
# 8   3.880000         72.0     242.0   73.0         73.0       23.7
# 9   4.570000         68.0     212.0   71.0          7.0       26.8
# 10  4.140000         65.0     420.0   69.0         68.0       30.3
# 11  4.360000         68.0      31.0   67.0         65.0       33.6
# 12  4.060000          7.0     998.0    7.0         68.0       36.7
# 13  4.430000         73.0     304.0   73.0         71.0       39.8
# 14  1.720000         76.0     529.0   76.0         75.0       42.1
# 15  1.680000         79.0    1483.0   78.0         78.0       43.5
#
#     Under-five Deaths    BMI   Population         GDP  \
# 0                 32.0   31.8    752263.0  118.693830
# 1                 34.0   31.3     75331.0  127.474620
# 2                 36.0    3.8    171161.0  111.227396
# 3                 39.0    3.3   1572466.0  955.648466
# 4                 42.0   29.9   1431776.0  839.927936
# 5                 44.0   29.4    128921.0  713.635620
# 6                 45.0   29.0    114554.0   65.824121
# 7                 46.0   28.6   9999617.0  325.678573
# 8                 46.0   28.2    985287.0  396.998217
# 9                 45.0   27.9     97529.0  414.796232
# 10                43.0   27.5   9556889.0  444.765750
# 11                42.0   27.1    949457.0  454.366654
# 12                41.0   26.7    926344.0  453.351155
# 13                40.0   26.3   9119178.0   57.348340
# 14                39.0   25.9   8976552.0  548.587312
# 15                39.0   25.5   8834733.0  547.358878
#
#     Country Status_Developed  Country Status_Developing  \
# 0                          0                          1
# 1                          0                          1
# 2                          0                          1
# 3                          0                          1
# 4                          0                          1
# 5                          0                          1
# 6                          0                          1
# 7                          0                          1
# 8                          0                          1
# 9                          0                          1
# 10                         0                          1
# 11                         0                          1
# 12                         0                          1
# 13                         0                          1
# 14                         0                          1
# 15                         0                          1
#
#     Avg_life_exp_per_cntry  Avg_GDP_per_cntry
# 0                  50.4875         410.980194
# 1                  50.4875         410.980194
# 2                  50.4875         410.980194
# 3                  50.4875         410.980194
# 4                  50.4875         410.980194
# 5                  50.4875         410.980194
# 6                  50.4875         410.980194
# 7                  50.4875         410.980194
# 8                  50.4875         410.980194
# 9                  50.4875         410.980194
# 10                 50.4875         410.980194
# 11                 50.4875         410.980194
# 12                 50.4875         410.980194
# 13                 50.4875         410.980194
# 14                 50.4875         410.980194
# 15                 50.4875         410.980194

# %% [markdown]
# ***Time Series Graph (Life Expectancy of Zimbabwe)***

# %%
plt.plot(min_life_expec_cntry['Year'], min_life_expec_cntry['Life Expectancy '], marker='o')

# Labelling
plt.xlabel("Year")
plt.ylabel("Life Expectancy")
plt.title("Life Expectancy vs Year (Zimbabwe- 2000 - 2015)")

# Display
plt.show()

# %% [markdown]
# ***Line Graph (Adult Mortality and Infant Deaths and Under-Five Deatsh vs Year)***

# %%
plt.figure(figsize=(7,5))
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry["Adult Mortality"], color='red', label='Adult Mortality')
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry["Infant Deaths"], color='blue', label='Infant Deaths')
plt.plot(max_life_expec_cntry['Year'], max_life_expec_cntry["Under-five Deaths "], color='green', label='Under-Five Deaths')
plt.xlabel("Year")
plt.ylabel("Parameter")
plt.title('Adult Mortality and Infant Deaths and Under-Five Deaths vs Year')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ***Box Plot (Adult Mortality (Zimbabwe) )***

# %%
#As can be seen from the above graph, no outliers are present in Adult Mortality and this can be verifiedby the following Box Plot
plt.boxplot(max_life_expec_cntry["Adult Mortality"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fca01793e50>,
#   <matplotlib.lines.Line2D at 0x7fca015d4130>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fca015d43d0>,
#   <matplotlib.lines.Line2D at 0x7fca015d4670>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fca01793bb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fca015d4910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fca015d4bb0>],
#  'means': []}

# %% [markdown]
# ***Bar Graph (Year vs GDP)***

# %%
plt.figure(figsize=(15,8))
plt.bar(max_life_expec_cntry['Year'], max_life_expec_cntry['GDP'], width=0.5, color="purple")
plt.title('Year vs GDP of Zimbabwe')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()

# %% [markdown]
# ***Pie Chart (avergage persons suffering from various diseases in Zimbabwe)***

# %%
df=min_life_expec_cntry.iloc[:,5:11]
df=pd.DataFrame(df.mean())
df
# Out:
#                       0
# Alcohol        4.542382
# Hepatitis B   70.562500
# Measles      923.000000
# Polio         75.625000
# Diphtheria    75.187500
#  HIV/AIDS     23.262500

# %% [markdown]
# ***Pie Chart (Diseases in Zimbabwe)***

# %%
world_total_infant_deaths = data.groupby('Year')['Infant Deaths'].sum().reset_index()
world_total_infant_deaths.head()
# Out:
#    Year  Infant Deaths
# 0  2000         4152.0
# 1  2001         4068.0
# 2  2002         3884.0
# 3  2003         3803.0
# 4  2004         3631.0

# %% [markdown]
# ***Point Plot (Total infant deaths in the world vs Year)***

# %%
plt.figure(figsize=(15,8))
sns.pointplot(x=world_total_infant_deaths['Year'],y=world_total_infant_deaths['Infant Deaths'])
plt.title("Total Infant Deaths in the World vs Year")
plt.show()

# %%
world_total_death_under5 = data.groupby('Year')['Under-five Deaths '].sum().reset_index()
world_total_death_under5.head()
# Out:
#    Year  Under-five Deaths
# 0  2000              5594.0
# 1  2001              5368.0
# 2  2002              5147.0
# 3  2003              4929.0
# 4  2004              4752.0

# %% [markdown]
# ***Point Plot (Total infant deaths and Under-Five Deaths in the world vs Year)***

# %%
plt.figure(figsize=(15,8))
sns.pointplot(x=world_total_infant_deaths['Year'],y=world_total_infant_deaths['Infant Deaths'], color='red', label="Infant Deaths")
sns.pointplot(x=world_total_death_under5['Year'],y=world_total_death_under5['Under-five Deaths '],color='brown', label="Under-Five Deaths")
plt.title('Total infant deaths and Under-Five Deaths in the world vs Year')
plt.xlabel('Year')
plt.ylabel('Total infant deaths and Under-Five Deaths in the world')
plt.show()

# %% [markdown]
# ***Histogram (Average Life Expectancy per country)***

# %%
plt.hist(data['Avg_life_exp_per_cntry'], bins =7)
# Out:
# (array([ 64.,  80.,  16., 128., 128., 288., 432.]),
#  array([50.4875    , 55.06607143, 59.64464286, 64.22321429, 68.80178571,
#         73.38035714, 77.95892857, 82.5375    ]),
#  <BarContainer object of 7 artists>)
